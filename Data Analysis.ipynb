# %% [markdown]
# # Samambaia Price House Prediction
#
# ## Table of contents
#
#  1. Problem definition
#  2. Two
#
#
#
#
# ## 1. Problem Definition
#
# ### 1.1 General objectives
#
# My family wants to buy a new house Distrito Federal State, Brazil. My uncle Fabio (ficticious name) have said that Samambaia is the best place for us to live. So, in order to help my family buy a good house in Samambaia, I will explore some houses in OLX and help them to make the best decision.
#
# For my family, the two most important features for a house or appartment are the number of bedrooms (3 or more) and the house price (between 180k and 300k). Another thing I consider important is choosing a good neighbor in Samambaia city - that probably increases the average value of the houses, but sometimes it's worth it for several reasons: there are more stores nearby, the train station is nearby, it's easier to sell it in the future, and so on. So, if we have to choose among houses of the same value, I will probably consider the neighbor which its average houses value is higher.
#
#
# ### 1.2 Specific objectives
#
# * Plot Samambaia Norte x Samambaia Sul average prices;
# * Plot Samambaia average prices per category;
# * Plot Samambaia average prices per neighborhood;
# * Plot Samambaia average prices for 3 or more bedrooms;
# * Plot Samambaia prices x house size;
#
#
# ## Import Libraries

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#column names
HOUSE_PRICE = 'new_house_price'
HOUSE_CATEGORY = 'house_category'
HOUSE_SIZE = 'house_size'
HOUSE_N_ROOMS = 'n_rooms'
HOUSE_REGION = 'Is_samambaia_norte'
HOUSE_HAS_CONDOMI = 'has_condominium'
HOUSE_CONDOMI_VALUE = 'value_condominium'
HOUSE_N_PARKING = 'n_parking'
HOUSE_HAS_PARKING = 'has_parking'
HOUSE_N_BATH = 'n_bathrooms'
HOUSE_CEP = 'CEP'
HOUSE_LOGRADOURO = 'Logradouro'

# %% [markdown]
# ## Reading the dataset

# %%
df_samambaia = pd.read_csv('./data/samambaia_houses.csv', index_col=[0])
df_samambaia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2926 entries, 0 to 2925
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   new_house_price     2926 non-null   float64
#  1   Is_samambaia_norte  2926 non-null   int64
#  2   n_rooms             2926 non-null   int64
#  3   has_condominium     2926 non-null   int64
#  4   value_condominium   2926 non-null   float64
#  5   has_parking         2926 non-null   int64
#  6   n_parking           2926 non-null   int64
#  7   house_size          2926 non-null   float64
#  8   house_hyperlink     2926 non-null   object
#  9   house_category      2498 non-null   object
#  10  n_bathrooms         2476 non-null   object
#  11  CEP                 2498 non-null   float64
#  12  Logradouro          2436 non-null   object
# dtypes: float64(4), int64(5), object(4)
# memory usage: 320.0+ KB

# %% [markdown]
# ## Filtering too much expensive houses
#
# #### The first thing to do is have a look at the variables using the describe method.

# %%
df_samambaia.describe()
# Out:
#        new_house_price  Is_samambaia_norte      n_rooms  has_condominium  \
# count     2.926000e+03         2926.000000  2926.000000      2926.000000
# mean      6.985153e+05            0.569036     2.383800         0.824334
# std       6.946811e+06            0.495296     0.935162         0.380601
# min       0.000000e+00            0.000000     0.000000         0.000000
# 25%       1.650000e+05            0.000000     2.000000         1.000000
# 50%       2.090000e+05            1.000000     2.000000         1.000000
# 75%       2.850000e+05            1.000000     3.000000         1.000000
# max       1.500000e+08            1.000000     5.000000         1.000000
#
#        value_condominium  has_parking    n_parking    house_size           CEP
# count        2926.000000  2926.000000  2926.000000   2926.000000  2.498000e+03
# mean          341.821941     0.775461     1.383800    126.509228  7.231657e+07
# std          7724.161203     0.417349     1.187397   1071.153251  1.252334e+04
# min             0.000000     0.000000     0.000000      0.000000  7.216120e+07
# 25%             0.000000     1.000000     1.000000     34.000000  7.230930e+07
# 50%             0.000000     1.000000     1.000000     54.000000  7.231821e+07
# 75%             0.000000     1.000000     2.000000    126.000000  7.232101e+07
# max        280000.000000     1.000000     5.000000  47600.000000  7.266031e+07

# %% [markdown]
# #### Taking a closer look at new_house_price, we can see that the mean is very high and the standard deviation is also high. This might happen when we have a few houses that are too much expensive compared to the rest of the dataset - also known as outliers. So, we will apply a threshold and see how the data looks like:

# %%
threshold = 10**6
df_samambaia_filtered = df_samambaia[df_samambaia['new_house_price'] < threshold]
df_samambaia_filtered.describe()
# Out:
#        new_house_price  Is_samambaia_norte      n_rooms  has_condominium  \
# count      2889.000000         2889.000000  2889.000000      2889.000000
# mean     231244.679820            0.571478     2.375562         0.823122
# std      117986.812973            0.494950     0.925836         0.381631
# min           0.000000            0.000000     0.000000         0.000000
# 25%      165000.000000            0.000000     2.000000         1.000000
# 50%      209000.000000            1.000000     2.000000         1.000000
# 75%      280000.000000            1.000000     3.000000         1.000000
# max      990000.000000            1.000000     5.000000         1.000000
#
#        value_condominium  has_parking    n_parking    house_size           CEP
# count        2889.000000  2889.000000  2889.000000   2889.000000  2.467000e+03
# mean          345.419522     0.775701     1.371409    121.765317  7.231658e+07
# std          7773.407465     0.417192     1.168089   1074.196268  1.256612e+04
# min             0.000000     0.000000     0.000000      0.000000  7.216120e+07
# 25%             0.000000     1.000000     1.000000     33.000000  7.230930e+07
# 50%             0.000000     1.000000     1.000000     54.000000  7.231821e+07
# 75%             0.000000     1.000000     2.000000    126.000000  7.232101e+07
# max        280000.000000     1.000000     5.000000  47600.000000  7.266031e+07

# %% [markdown]
# #### It looks much better now. Just to make sure we didn't lose too much of the dataset, let's see how many we have left:

# %%
total_size = df_samambaia.shape[0]
new_size = df_samambaia_filtered.shape[0]
percent = new_size/total_size
diff = total_size - new_size

print(f'The filtered dataset has {diff} less instances than the original dataset of {total_size} instances.')
print(f'That represent {percent} of the data in the filtered dataset. So, it was worth it!')
# Out:
# The filtered dataset has 37 less instances than the original dataset of 2926 instances.
# That represent 0.9873547505126452 of the data in the filtered dataset. So, it was worth it!

# %% [markdown]
# #### So, we will work on the filtered dataset, df_samambaia_filtered
#
# ## Samambaia norte x Samambaia sul

# %%
fig = px.box(data_frame=df_samambaia_filtered, x=HOUSE_CATEGORY, y=HOUSE_PRICE)

fig.show()

# REMOVER TAMBÉM OS MUITO BARATOS. TÁ ERRADO PROVAVELMENTE!!!
# Out:
# <div>                            <div id="0e802fd6-4080-4540-b1c6-e68b77dba00d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e802fd6-4080-4540-b1c6-e68b77dba00d")) {                    Plotly.newPlot(                        "0e802fd6-4080-4540-b1c6-e68b77dba00d",                        [{"alignmentgroup":"True","hovertemplate":"house_category=%{x}<br>new_house_price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Apartamentos","Apartamentos","Apartamentos","Apartamentos","Casas","Apartamentos","Apartamentos","Casas","Apartamentos","Apartamentos","Casas","Casas","Casas","Apartamentos","Apartamentos","Casas","Casas","Apartamentos","Apartamentos","Casas","Casas","Casas","Casas","Apartamentos","Apartamentos","Casas","Apartamentos","Casas","Apartamentos","Apartamentos","Apartamentos","Apartamentos","Apartamentos","Apartamentos","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Apartamentos","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Apartamentos","Apartamentos","Apartamentos",null,"Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Casas","Apartamentos","Casas","Apartamentos","Apartamentos","Casas","Casas",null,"Apartamentos","Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Apartamentos","Casas","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Apartamentos","Apartamentos","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas",null,"Casas","Casas","Casas","Casas","Apartamentos",null,"Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Apartamentos","Casas","Casas","Apartamentos",null,null,"Apartamentos","Casas","Apartamentos","Casas","Apartamentos","Apartamentos",null,"Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Casas",null,"Apartamentos","Apartamentos","Casas","Casas","Casas","Casas","Casas","Apartamentos",null,"Apartamentos","Casas",null,null,null,null,null,null,"Apartamentos","Casas","Casas","Apartamentos","Casas","Apartamentos","Apartamentos","Casas","Casas",null,null,null,null,null,"Casas","Casas",null,null,"Casas","Casas","Casas",null,null,null,null,null,"Casas",null,null,null,"Casas","Casas","Apartamentos","Casas",null,null,null,null,"Casas","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas",null,"Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Casas","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas","Apartamentos","Casas","Casas","Casas","Apartamentos","Apartamentos","Casas","Casas","Casas","Casas","Casas","Casas",null,null,"Apartamentos","Apa ...

# %%
df_samambaia['new_house_price'].mean()
# Out:
# 698515.3376623377

# %%
df_samambaia
# Out:
#       new_house_price  Is_samambaia_norte  n_rooms  has_condominium  \
# 0            152000.0                   0        1                1
# 1            408000.0                   0        2                1
# 2            145000.0                   1        2                1
# 3            190000.0                   0        2                1
# 4            290000.0                   1        2                0
# ...               ...                 ...      ...              ...
# 2921         168000.0                   1        2                1
# 2922         168000.0                   1        2                1
# 2923         168000.0                   1        2                1
# 2924         212060.0                   0        2                1
# 2925         212000.0                   1        2                1
#
#       value_condominium  has_parking  n_parking  house_size  \
# 0                 329.0            0          0        38.0
# 1                 432.0            1          1        65.0
# 2                  10.0            0          0        63.0
# 3                 350.0            1          1        55.0
# 4                   0.0            1          1       105.0
# ...                 ...          ...        ...         ...
# 2921                0.0            0          0        33.0
# 2922                0.0            1          1        33.0
# 2923                0.0            1          1        33.0
# 2924                0.0            1          1        42.0
# 2925                0.0            0          0        33.0
#
#                                         house_hyperlink house_category  \
# 0     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 1     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 3     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 4     https://df.olx.com.br/distrito-federal-e-regia...          Casas
# ...                                                 ...            ...
# 2921  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2922  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2923  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2924  https://df.olx.com.br/distrito-federal-e-regia...            NaN
# 2925  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
#
#      n_bathrooms         CEP                    Logradouro
# 0              1  72302705.0  QR 116 Conjunto 4-A Comércio
# 1              2  72300533.0         Quadra 301 Conjunto 2
# 2              1  72316080.0                        QR 204
# 3              1  72304051.0             QN 120 Conjunto 1
# 4              1  72318030.0            QR 402 Conjunto 29
# ...          ...         ...                           ...
# 2921           1  72321000.0                        QR 407
# 2922           1  72321000.0                        QR 407
# 2923           1  72321000.0                        QR 407
# 2924         NaN         NaN                           NaN
# 2925           1  72321003.0             QR 407 Conjunto 3
#
# [2926 rows x 13 columns]
