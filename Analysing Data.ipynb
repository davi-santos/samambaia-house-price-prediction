# %%
import pandas as pd

# %%
df_processed_data = pd.read_csv('./data/processed_data.csv', index_col=[0])
df_new_data = pd.read_csv('./data/new_data.csv', index_col=[0])

# %%
df_processed_data
# Out:
#       new_house_price  Is_samambaia_norte  n_rooms  has_condominium  \
# 0            152000.0                   0        1                1
# 1            408000.0                   0        2                1
# 2            145000.0                   1        2                1
# 3            190000.0                   0        2                1
# 4            290000.0                   1        2                0
# ...               ...                 ...      ...              ...
# 2921         168000.0                   1        2                1
# 2922         168000.0                   1        2                1
# 2923         168000.0                   1        2                1
# 2924         212060.0                   0        2                1
# 2925         212000.0                   1        2                1
#
#       value_condominium  has_parking  n_parking  house_size  \
# 0                 329.0            0          0        38.0
# 1                 432.0            1          1        65.0
# 2                  10.0            0          0        63.0
# 3                 350.0            1          1        55.0
# 4                   0.0            1          1       105.0
# ...                 ...          ...        ...         ...
# 2921                0.0            0          0        33.0
# 2922                0.0            1          1        33.0
# 2923                0.0            1          1        33.0
# 2924                0.0            1          1        42.0
# 2925                0.0            0          0        33.0
#
#                                         house_hyperlink
# 0     https://df.olx.com.br/distrito-federal-e-regia...
# 1     https://df.olx.com.br/distrito-federal-e-regia...
# 2     https://df.olx.com.br/distrito-federal-e-regia...
# 3     https://df.olx.com.br/distrito-federal-e-regia...
# 4     https://df.olx.com.br/distrito-federal-e-regia...
# ...                                                 ...
# 2921  https://df.olx.com.br/distrito-federal-e-regia...
# 2922  https://df.olx.com.br/distrito-federal-e-regia...
# 2923  https://df.olx.com.br/distrito-federal-e-regia...
# 2924  https://df.olx.com.br/distrito-federal-e-regia...
# 2925  https://df.olx.com.br/distrito-federal-e-regia...
#
# [2926 rows x 9 columns]

# %%
df_new_data
# Out:
#      house_category n_bathrooms         CEP                    Logradouro
# 0      Apartamentos           1  72302705.0  QR 116 Conjunto 4-A Comércio
# 1      Apartamentos           2  72300533.0         Quadra 301 Conjunto 2
# 2      Apartamentos           1  72316080.0                        QR 204
# 3      Apartamentos           1  72304051.0             QN 120 Conjunto 1
# 4             Casas           1  72318030.0            QR 402 Conjunto 29
# ...             ...         ...         ...                           ...
# 2921   Apartamentos           1  72321000.0                        QR 407
# 2922   Apartamentos           1  72321000.0                        QR 407
# 2923   Apartamentos           1  72321000.0                        QR 407
# 2924            NaN         NaN         NaN                           NaN
# 2925   Apartamentos           1  72321003.0             QR 407 Conjunto 3
#
# [2926 rows x 4 columns]

# %%
df_ = pd.concat([df_processed_data, df_new_data], axis=1)

# %%
df_
# Out:
#       new_house_price  Is_samambaia_norte  n_rooms  has_condominium  \
# 0            152000.0                   0        1                1
# 1            408000.0                   0        2                1
# 2            145000.0                   1        2                1
# 3            190000.0                   0        2                1
# 4            290000.0                   1        2                0
# ...               ...                 ...      ...              ...
# 2921         168000.0                   1        2                1
# 2922         168000.0                   1        2                1
# 2923         168000.0                   1        2                1
# 2924         212060.0                   0        2                1
# 2925         212000.0                   1        2                1
#
#       value_condominium  has_parking  n_parking  house_size  \
# 0                 329.0            0          0        38.0
# 1                 432.0            1          1        65.0
# 2                  10.0            0          0        63.0
# 3                 350.0            1          1        55.0
# 4                   0.0            1          1       105.0
# ...                 ...          ...        ...         ...
# 2921                0.0            0          0        33.0
# 2922                0.0            1          1        33.0
# 2923                0.0            1          1        33.0
# 2924                0.0            1          1        42.0
# 2925                0.0            0          0        33.0
#
#                                         house_hyperlink house_category  \
# 0     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 1     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 3     https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 4     https://df.olx.com.br/distrito-federal-e-regia...          Casas
# ...                                                 ...            ...
# 2921  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2922  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2923  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
# 2924  https://df.olx.com.br/distrito-federal-e-regia...            NaN
# 2925  https://df.olx.com.br/distrito-federal-e-regia...   Apartamentos
#
#      n_bathrooms         CEP                    Logradouro
# 0              1  72302705.0  QR 116 Conjunto 4-A Comércio
# 1              2  72300533.0         Quadra 301 Conjunto 2
# 2              1  72316080.0                        QR 204
# 3              1  72304051.0             QN 120 Conjunto 1
# 4              1  72318030.0            QR 402 Conjunto 29
# ...          ...         ...                           ...
# 2921           1  72321000.0                        QR 407
# 2922           1  72321000.0                        QR 407
# 2923           1  72321000.0                        QR 407
# 2924         NaN         NaN                           NaN
# 2925           1  72321003.0             QR 407 Conjunto 3
#
# [2926 rows x 13 columns]
